# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
# %matplotlib inline

import nltk

# %%
df = pd.read_pickle('../Data/All_Friends_data.plk')

# %%
df.head(50)
# Out:
#      Speaker                                               Text Episode  \
# 0     monica   oh, the way you crushed mike at ping pong was...    1001
# 1   chandler     you know, i'd love to, but i'm a little tired.    1001
# 2     monica                i'll put a pillowcase over my head.    1001
# 3   chandler                                         you're on!    1001
# 4     phoebe                                               hey!    1001
# 5     monica                                         what's up?    1001
# 6     phoebe   well, okay, mike's taking a shower, which by ...    1001
# 7       ross                                     ... finally...    1001
# 8     phoebe                                      is that ross?    1001
# 9     monica   yeah, you can hear everything through these s...    1001
# 10    phoebe                     sounds like he's with someone.    1001
# 11  chandler   he could be alone. this morning i heard him d...    1001
# ...

# %%
df[df.Speaker == '[ scene']
# Out:
#       Speaker                                               Text Episode  \
# 1070  [ scene   the freeway. rachel is driving monica's porsc...    1004
# 1089  [ scene   rachel and joey's apartment. chandler, monica...    1004
#
#                                                   Scene
# 1070  [scene joey’s apartment. ross is filming his p...
# 1089  [scene joey’s apartment. ross is filming his p...

# %%
# [i.replace('(', ' ').replace(')', ' ').split(' ') for i in list(df.Speaker.unique())]
[i.split(' ') for i in list(df.Speaker.unique())]
# Out:
# [['monica'],
#  ['chandler'],
#  ['phoebe'],
#  ['ross'],
#  ['charlie'],
#  ['rachel'],
#  ['joey'],
#  ['monica,', 'chandler', 'and', 'phoebe'],
#  ["joey's", 'voice,', 'but', 'she', 'sees', 'ross'],
#  ["joey's", 'voice/ross'],
#  ['rachel/ross'],
#  ['both'],
#  ['mike'],
#  ['precious'],
#  ['joey', '(to', 'rachel)'],
#  ['joey', 'and', 'rachel'],
#  ['frank', 'jr.'],
#  ['monica', '(reads', 'a', 'form', 'in', 'her', 'lap)'],
#  ['colleen'],
#  ['bill'],
#  ['owen'],
#  ['frank', 'jr.', '(looks', 'at', 'the', 'triplets)'],
#  ['chandler', '(to', 'monica)'],
#  ['ross', '(on', 'the', 'verge', 'of', 'tears)'],
#  ['ross', 'and', 'chandler'],
#  ['assistant'],
#  ['amanda'],
#  ['rachel', 'and', 'joey'],
#  ['glenda'],
#  ['ross,', 'rachel', 'and', 'chandler'],
#  ['rachel', 'and', 'phoebe'],
#  ['jack', 'and', 'judy'],
#  ['jack'],
#  ['judy'],
#  ['chandler', '(nearly', 'weeping)'],
#  ['everybody'],
#  ['ross', '(stops', 'recording)'],
#  ['phoebe', '(sees', 'the', 'cake)'],
# ...

# %%
# List of existing names:
Names = nltk.corpus.names.words()
